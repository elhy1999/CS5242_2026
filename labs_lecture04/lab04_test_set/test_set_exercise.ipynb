# %% [markdown]
# # Lab 04 : Test set evaluation -- exercise

# %%
# For Google Colaboratory
import sys, os
if 'google.colab' in sys.modules:
    # mount google drive
    from google.colab import drive
    drive.mount('/content/gdrive')
    path_to_file = '/content/gdrive/My Drive/CS5242_2026_codes/labs_lecture04/lab04_test_set'
    print(path_to_file)
    # change current path to the folder containing "file_name"
    os.chdir(path_to_file)
    # !pwd

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from random import randint
import utils

# %% [markdown]
# ### Download the CIFAR dataset -- check the size carefully!

# %%
from utils import check_cifar_dataset_exists
data_path=check_cifar_dataset_exists()

train_data=torch.load(data_path+'cifar/train_data.pt')
train_label=torch.load(data_path+'cifar/train_label.pt')
test_data=torch.load(data_path+'cifar/test_data.pt')
test_label=torch.load(data_path+'cifar/test_label.pt')

print(train_data.size())
# Out:
# torch.Size([50000, 3, 32, 32])

# %% [markdown]
# ### Make a ONE layer net class.

# %%
class one_layer_net(nn.Module):

    def __init__(self, input_size, output_size):
        super(one_layer_net , self).__init__()
        self.linear_layer = nn.Linear( input_size, output_size , bias=True)
        
    def forward(self, x):
        scores = self.linear_layer(x)
        return scores

# %% [markdown]
# ### Build the net.

# %%
net=one_layer_net(3072,10)
print(net)
# Out:
# one_layer_net(
#   (linear_layer): Linear(in_features=3072, out_features=10, bias=True)
# )

# %% [markdown]
# ### Choose the criterion and optimizer. Also choose:

# %%
criterion = nn.CrossEntropyLoss()
optimizer=torch.optim.SGD( net.parameters() , lr=0.01 )
bs=20

# %% [markdown]
# ### Do 50 passes through the training set.

# %%
for epoch in range(50):
    
    running_loss=0
    running_error=0
    num_batches=0
    
    shuffled_indices=torch.randperm(50000)
 
    for count in range(0,50000,bs):
    
        # Set the gradients to zeros
        optimizer.zero_grad()
        
        # create a minibatch       
        indices=shuffled_indices[count:count+bs]
        minibatch_data =  train_data[indices]
        minibatch_label= train_label[indices]

        # reshape the minibatch
        inputs = minibatch_data.view(bs,3072)

        # tell Pytorch to start tracking all operations that will be done on "inputs"
        inputs.requires_grad_()

        # forward the minibatch through the net 
        scores=net( inputs ) 

        # Compute the average of the losses of the data points in the minibatch
        loss =  criterion( scores , minibatch_label) 
        
        # backward pass to compute dL/dU, dL/dV and dL/dW   
        loss.backward()

        # do one step of stochastic gradient descent: U=U-lr(dL/dU), V=V-lr(dL/dU), ...
        optimizer.step()
        
        # START COMPUTING STATS
        
        # add the loss of this batch to the running loss
        running_loss += loss.detach().item()
        
        # compute the error made on this batch and add it to the running error       
        error = utils.get_error( scores.detach() , minibatch_label)
        running_error += error.item()
        
        num_batches+=1
    
    
    # compute stats for the full training set
    total_loss = running_loss/num_batches
    total_error = running_error/num_batches
    
    print('epoch=',epoch, '\t loss=', total_loss , '\t error=', total_error*100 ,'percent')
# Out:
# epoch= 0 	 loss= 1.9551456354141235 	 error= 69.48999994277955 percent
# epoch= 1 	 loss= 1.8660079778671264 	 error= 65.20399996042252 percent
# epoch= 2 	 loss= 1.8375817760705948 	 error= 63.96399997472763 percent
# epoch= 3 	 loss= 1.8187167271614075 	 error= 63.276000006198885 percent
# epoch= 4 	 loss= 1.8052418026447297 	 error= 62.92399995565414 percent
# epoch= 5 	 loss= 1.7983455195188522 	 error= 62.340000035762785 percent
# epoch= 6 	 loss= 1.7899549256324767 	 error= 62.26799997806549 percent
# epoch= 7 	 loss= 1.7796394896745682 	 error= 61.61800004482269 percent
# epoch= 8 	 loss= 1.7786065605163575 	 error= 61.85400001049042 percent
# epoch= 9 	 loss= 1.7721981180667876 	 error= 61.29200002193451 percent
# epoch= 10 	 loss= 1.7662641134738921 	 error= 61.24400002241135 percent
# epoch= 11 	 loss= 1.769739089345932 	 error= 61.21199999809265 percent
# epoch= 12 	 loss= 1.7626867393016816 	 error= 61.00799998283386 percent
# epoch= 13 	 loss= 1.7571775130033493 	 error= 60.70200002670288 percent
# epoch= 14 	 loss= 1.7584676951885223 	 error= 60.62400001764298 percent
# epoch= 15 	 loss= 1.7552039151906966 	 error= 60.478000009059905 percent
# epoch= 16 	 loss= 1.7525633417129516 	 error= 60.56800003528595 percent
# epoch= 17 	 loss= 1.750889092350006 	 error= 60.60800007343292 percent
# epoch= 18 	 loss= 1.7450804921627046 	 error= 60.07000003814697 percent
# epoch= 19 	 loss= 1.7432219656944274 	 error= 60.19599996089935 percent
# epoch= 20 	 loss= 1.7453771238327027 	 error= 60.16999999761582 percent
# epoch= 21 	 loss= 1.7441740433216095 	 error= 60.15000001907349 percent
# epoch= 22 	 loss= 1.737560173535347 	 error= 59.91199999809265 percent
# epoch= 23 	 loss= 1.7356811816453934 	 error= 59.62599997282029 percent
# epoch= 24 	 loss= 1.7404783412218094 	 error= 59.95399991512299 percent
# epoch= 25 	 loss= 1.735734034538269 	 error= 60.0419999551773 percent
# epoch= 26 	 loss= 1.7342216144561768 	 error= 59.62200000286102 percent
# epoch= 27 	 loss= 1.7305180976629257 	 error= 59.294000074863426 percent
# epoch= 28 	 loss= 1.7325273169755935 	 error= 59.722000031471254 percent
# epoch= 29 	 loss= 1.7280603798151015 	 error= 59.508000009059906 percent
# epoch= 30 	 loss= 1.7296655668497085 	 error= 59.72400000333786 percent
# epoch= 31 	 loss= 1.72576905503273 	 error= 59.449999973773956 percent
# epoch= 32 	 loss= 1.724803070163727 	 error= 59.23400000333786 percent
# epoch= 33 	 loss= 1.7243950642347337 	 error= 59.46200003147125 percent
# epoch= 34 	 loss= 1.7244644127130508 	 error= 59.325999970436094 percent
# epoch= 35 	 loss= 1.7231889358520507 	 error= 59.418000104427335 percent
# epoch= 36 	 loss= 1.722174947118759 	 error= 59.04799999952316 percent
# epoch= 37 	 loss= 1.7227141929149627 	 error= 59.21799999713898 percent
# epoch= 38 	 loss= 1.7195397917747497 	 error= 59.151999986171724 percent
# epoch= 39 	 loss= 1.7162811123371124 	 error= 58.95199998378754 percent
# epoch= 40 	 loss= 1.716528107047081 	 error= 58.741999969482414 percent
# epoch= 41 	 loss= 1.7198546196699143 	 error= 59.23000001192092 percent
# epoch= 42 	 loss= 1.7179575174808501 	 error= 58.90400000572205 percent
# epoch= 43 	 loss= 1.7151116084575653 	 error= 58.85000000953674 percent
# epoch= 44 	 loss= 1.7153718387842178 	 error= 59.0380000591278 percent
# epoch= 45 	 loss= 1.71567739007473 	 error= 58.82800001382827 percent
# epoch= 46 	 loss= 1.714453353047371 	 error= 59.13199998617172 percent
# epoch= 47 	 loss= 1.7094320917129517 	 error= 58.8259999871254 percent
# epoch= 48 	 loss= 1.7068003824234008 	 error= 58.58399998903274 percent
# epoch= 49 	 loss= 1.7082916027069093 	 error= 58.69200004339218 percent

# %% [markdown]
# # You only have to complete this cell

# %% [markdown]
# ### So we are doing around 59% error on the training set. BUT how much are we doing on test set?

# %%
running_error=0 # COMPLETE HERE
num_batches=0 # COMPLETE HERE


for i in range(0, test_data.size(0), bs): # COMPLETE HERE

    # extract the minibatch
    minibatch_data = test_data[i: i + bs] # COMPLETE HERE
    minibatch_label= test_label[i: i + bs]  # COMPLETE HERE

    # reshape the minibatch
    inputs = minibatch_data.view(-1, 3 * 32 * 32) # COMPLETE HERE

    # feed it to the network
    scores = net(inputs) # COMPLETE HERE

    # compute the error made on this batch
    error = utils.get_error(scores, minibatch_label) # COMPLETE HERE
    
    # add it to the running error
    running_error += error # COMPLETE HERE

    num_batches += 1 # COMPLETE HERE


# compute error rate on the full test set
total_error = running_error / num_batches # COMPLETE HERE

print( 'error rate on test set =', total_error*100 ,'percent')
# Out:
# error rate on test set = tensor(61.3900) percent

# %% [markdown]
# ### Choose image at random from the test set and see how good/bad are the predictions

# %%
# choose a picture at random
idx=randint(0, 10000-1)
im=test_data[idx]

# diplay the picture
utils.show(im)

# feed it to the net and display the confidence scores
scores =  net( im.view(1,3072)) 
probs= torch.softmax(scores, dim=1)
utils.show_prob_cifar(probs)
